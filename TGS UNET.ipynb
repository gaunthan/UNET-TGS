# %%
import os
from pathlib import Path
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
# Set some parameters
im_width = 128
im_height = 128
border = 5
DATASET_PATH = "tgs-salt-identification-challenge/train"
image_path = Path(DATASET_PATH) / 'images'
mask_path = Path(DATASET_PATH) / 'masks'

# %%
ids = next(os.walk(image_path))[2] # list of names all images in the given path
print("No. of images = ", len(ids))
# Out:
# No. of images =  4000

# %%
X = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)
y = np.zeros((len(ids), im_height, im_width, 1), dtype=np.float32)

# %% [markdown]
# #### Load the images and masks into arrays

# %%
# tqdm is used to display the progress bar
for n, id_ in tqdm_notebook(enumerate(ids), total=len(ids)):
    # Load images
    img = load_img(image_path / id_, grayscale=True)
    x_img = img_to_array(img)
    x_img = resize(x_img, (128, 128, 1), mode = 'constant', preserve_range = True)
    # Load masks
    mask = img_to_array(load_img(mask_path / id_, grayscale=True))
    mask = resize(mask, (128, 128, 1), mode = 'constant', preserve_range = True)
    # Save images
    X[n] = x_img/255.0
    y[n] = mask/255.0
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))
# /home/kerry/.local/lib/python3.7/site-packages/keras_preprocessing/image.py:492: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
# Split train and valid
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# #### Below code can be used to visualize the images and corresponding masks

# %%
# Visualize any randome image along with the mask
ix = random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0 # salt indicator

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 15))

ax1.imshow(X_train[ix, ..., 0], cmap = 'seismic', interpolation = 'bilinear')
if has_mask: # if salt
    # draw a boundary(contour) in the original image separating salt and non-salt areas
    ax1.contour(y_train[ix].squeeze(), colors = 'k', linewidths = 5, levels = [0.5])
ax1.set_title('Seismic')

ax2.imshow(y_train[ix].squeeze(), cmap = 'gray', interpolation = 'bilinear')
ax2.set_title('Salt')
# Out:
# Text(0.5, 1.0, 'Salt')

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def get_unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((im_height, im_width, 1), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 16) 160         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128, 128, 16) 64          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 16)   0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 16)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 32)   4640        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 32)   128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 32)   0           activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 32)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 64)   18496       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 16, 16, 64)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  73856       dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 128)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 128)    0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 256)    295168      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 256)    1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 256)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 16, 16, 128)  295040      activation_28[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_5[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 128)  295040      dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 128)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 32, 32, 64)   73792       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_6[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 64)   73792       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 32)   18464       activation_32[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_7[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 64)   0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 32)   18464       dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 64, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 32)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 128, 128, 16) 4624        activation_34[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_8[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128, 128, 32) 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 16) 4624        dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 128, 128, 16) 64          conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 128, 128, 16) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 1)  17          activation_36[0][0]
# ==================================================================================================
# Total params: 1,179,121
# Trainable params: 1,177,649
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-tgs-salt.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
results = model.fit(X_train, y_train, batch_size=32, epochs=50, callbacks=callbacks,\
                    validation_data=(X_valid, y_valid))
# Out:
# WARNING:tensorflow:From /home/kerry/anaconda3/envs/keras-gpu/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 3600 samples, validate on 400 samples
# Epoch 1/50
# 3600/3600 [==============================] - 8s 2ms/step - loss: 0.3846 - acc: 0.8330 - val_loss: 1.1650 - val_acc: 0.5620
#
# Epoch 00001: val_loss improved from inf to 1.16498, saving model to model-tgs-salt.h5
# Epoch 2/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.2966 - acc: 0.8766 - val_loss: 0.6031 - val_acc: 0.7588
#
# Epoch 00002: val_loss improved from 1.16498 to 0.60310, saving model to model-tgs-salt.h5
# Epoch 3/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.2783 - acc: 0.8835 - val_loss: 0.8627 - val_acc: 0.7307
#
# Epoch 00003: val_loss did not improve from 0.60310
# Epoch 4/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.2636 - acc: 0.8883 - val_loss: 0.4606 - val_acc: 0.8137
#
# Epoch 00004: val_loss improved from 0.60310 to 0.46064, saving model to model-tgs-salt.h5
# Epoch 5/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.2473 - acc: 0.8946 - val_loss: 0.7343 - val_acc: 0.7145
#
# Epoch 00005: val_loss did not improve from 0.46064
# Epoch 6/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.2428 - acc: 0.8952 - val_loss: 0.6665 - val_acc: 0.7827
#
# Epoch 00006: val_loss did not improve from 0.46064
# Epoch 7/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.2276 - acc: 0.9029 - val_loss: 0.4068 - val_acc: 0.8326
#
# Epoch 00007: val_loss improved from 0.46064 to 0.40683, saving model to model-tgs-salt.h5
# Epoch 8/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.2236 - acc: 0.9037 - val_loss: 0.3701 - val_acc: 0.8411
#
# Epoch 00008: val_loss improved from 0.40683 to 0.37013, saving model to model-tgs-salt.h5
# Epoch 9/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.2147 - acc: 0.9065 - val_loss: 0.3196 - val_acc: 0.8578
#
# Epoch 00009: val_loss improved from 0.37013 to 0.31965, saving model to model-tgs-salt.h5
# Epoch 10/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.2083 - acc: 0.9095 - val_loss: 0.5125 - val_acc: 0.7684
#
# Epoch 00010: val_loss did not improve from 0.31965
# Epoch 11/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.2046 - acc: 0.9100 - val_loss: 0.3532 - val_acc: 0.8597
#
# Epoch 00011: val_loss did not improve from 0.31965
# Epoch 12/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1938 - acc: 0.9155 - val_loss: 0.2450 - val_acc: 0.8993
#
# Epoch 00012: val_loss improved from 0.31965 to 0.24496, saving model to model-tgs-salt.h5
# Epoch 13/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1902 - acc: 0.9158 - val_loss: 0.3064 - val_acc: 0.8755
#
# Epoch 00013: val_loss did not improve from 0.24496
# Epoch 14/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1767 - acc: 0.9214 - val_loss: 0.3135 - val_acc: 0.8751
#
# Epoch 00014: val_loss did not improve from 0.24496
# Epoch 15/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1787 - acc: 0.9196 - val_loss: 0.3338 - val_acc: 0.8478
#
# Epoch 00015: val_loss did not improve from 0.24496
# Epoch 16/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1787 - acc: 0.9207 - val_loss: 0.2772 - val_acc: 0.8813
#
# Epoch 00016: val_loss did not improve from 0.24496
# Epoch 17/50
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1678 - acc: 0.9241 - val_loss: 0.4090 - val_acc: 0.8167
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00017: val_loss did not improve from 0.24496
# Epoch 18/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1483 - acc: 0.9311 - val_loss: 0.2312 - val_acc: 0.8972
#
# Epoch 00018: val_loss improved from 0.24496 to 0.23117, saving model to model-tgs-salt.h5
# Epoch 19/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1385 - acc: 0.9369 - val_loss: 0.2200 - val_acc: 0.9025
#
# Epoch 00019: val_loss improved from 0.23117 to 0.21996, saving model to model-tgs-salt.h5
# Epoch 20/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1339 - acc: 0.9384 - val_loss: 0.2160 - val_acc: 0.9050
#
# Epoch 00020: val_loss improved from 0.21996 to 0.21602, saving model to model-tgs-salt.h5
# Epoch 21/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1317 - acc: 0.9394 - val_loss: 0.2151 - val_acc: 0.9013
#
# Epoch 00021: val_loss improved from 0.21602 to 0.21512, saving model to model-tgs-salt.h5
# Epoch 22/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1295 - acc: 0.9399 - val_loss: 0.2177 - val_acc: 0.9043
#
# Epoch 00022: val_loss did not improve from 0.21512
# Epoch 23/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1291 - acc: 0.9403 - val_loss: 0.2113 - val_acc: 0.9063
#
# Epoch 00023: val_loss improved from 0.21512 to 0.21134, saving model to model-tgs-salt.h5
# Epoch 24/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1259 - acc: 0.9413 - val_loss: 0.2146 - val_acc: 0.9004
#
# Epoch 00024: val_loss did not improve from 0.21134
# Epoch 25/50
# 3600/3600 [==============================] - 5s 1ms/step - loss: 0.1246 - acc: 0.9421 - val_loss: 0.2132 - val_acc: 0.9033
#
# Epoch 00025: val_loss did not improve from 0.21134
# Epoch 26/50
# 3600/3600 [==============================] - 6s 2ms/step - loss: 0.1241 - acc: 0.9413 - val_loss: 0.2263 - val_acc: 0.8982
#
# Epoch 00026: val_loss did not improve from 0.21134
# Epoch 27/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1226 - acc: 0.9425 - val_loss: 0.2215 - val_acc: 0.8973
#
# Epoch 00027: val_loss did not improve from 0.21134
# Epoch 28/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1204 - acc: 0.9437 - val_loss: 0.2232 - val_acc: 0.9067
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00028: val_loss did not improve from 0.21134
# Epoch 29/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1191 - acc: 0.9446 - val_loss: 0.2222 - val_acc: 0.9027
#
# Epoch 00029: val_loss did not improve from 0.21134
# Epoch 30/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1179 - acc: 0.9447 - val_loss: 0.2235 - val_acc: 0.9018
#
# Epoch 00030: val_loss did not improve from 0.21134
# Epoch 31/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1150 - acc: 0.9458 - val_loss: 0.2241 - val_acc: 0.9007
#
# Epoch 00031: val_loss did not improve from 0.21134
# Epoch 32/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1155 - acc: 0.9457 - val_loss: 0.2215 - val_acc: 0.9025
#
# Epoch 00032: val_loss did not improve from 0.21134
# Epoch 33/50
# 3600/3600 [==============================] - 5s 2ms/step - loss: 0.1151 - acc: 0.9454 - val_loss: 0.2203 - val_acc: 0.9032
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00033: val_loss did not improve from 0.21134
# Epoch 00033: early stopping

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %% [markdown]
# ### Inference

# %%
# load the best model
model.load_weights('model-tgs-salt.h5')

# %%
# Evaluate on validation set (this must be equals to the best log_loss)
model.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 400/400 [==============================] - 0s 445us/step
# [0.21134086489677428, 0.90625732421875]

# %%
# Predict on train, val and test
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 3600/3600 [==============================] - 2s 453us/step
# 400/400 [==============================] - 0s 389us/step

# %%
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    """Function to plot the results"""
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Seismic')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Salt')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Salt Predicted')
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Salt Predicted binary');

# %% [markdown]
# ### Predictions on training set

# %%
# Check if training data looks all right
plot_sample(X_train, y_train, preds_train, preds_train_t, ix=14)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %%
plot_sample(X_train, y_train, preds_train, preds_train_t)

# %% [markdown]
# ### Predictions on test set

# %%
# Check if valid data looks all right
plot_sample(X_valid, y_valid, preds_val, preds_val_t, ix=19)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)

# %%
plot_sample(X_valid, y_valid, preds_val, preds_val_t)
